# %% [markdown]
# # Software Coaching for Python
# # Week 2: Advanced Web Scraping - Homework

# %% [markdown]
# Instructor: Kang-Pyo Lee

# %%
from google.colab import drive

drive.mount('/content/gdrive')
path = "/content/gdrive/Shareddrives/Software_Coaching_Fall_2021"
my_folder = "HLP"     # *** REPLACE WITH YOUR FOLDER NAME ***
outcome_folder = f"{path}/{my_folder}/outcome"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Import the <b>requests</b> package and the <b>BeautifulSoup</b> module from the <b>bs4</b> package . You are going to extract information from one of the webpages on DataScienceCentral.com: https://www.datasciencecentral.com/profiles/blogs/beautiful-mathematical-images. Fetch the HTML content from the webpage and then create a BeautifulSoup object named `soup` to parse the HTML content.

# %%
# Your answer here
import requests
from bs4 import BeautifulSoup
url="https://www.datasciencecentral.com/profiles/blogs/beautiful-mathematical-images"
r=requests.get(url)
soup=BeautifulSoup(r.content,"html.parser")

# %% [markdown]
# 1\. Get the title text of the article, not of the webpage, which is '*Beautiful Mathematical Images*', and save it in the `ans1` variable.

# %%
# Your answer here
ans1=soup.find("div",{"class":"tb"}).find("h1")

# %%
# Check your answer here. (Do not make any change to this cell. Just run this cell.)
ans1.text
# Out:
# 'Beautiful Mathematical Images'

# %% [markdown]
# 2\. Right below the article title, there is a text referring to the author, '*Vincent Granville*', followed by another text referring to the posting date and time, '*on February 2, 2021 at 10:30am*'. Get the two texts and save them in the variables `ans2_1` and `ans2_2`, respectively. Strip out unnecessary leading or trailing whitespaces.
#
# [Hint] Each of the two texts is defined in an a element. Focus on finding those two a elements. You may need hierarchical search.

# %%
# Your answer here
a=soup.find("ul",{"class":"navigation byline"}).find_all("a")
print(a)
ans2_1=a[1].text
ans2_2=a[2].text
# Out:
# [<a class="nolink">Posted by </a>, <a href="/profile/VincentGranville">Vincent Granville</a>, <a class="nolink"> on February 2, 2021 at 10:30am</a>, <a class="xg_sprite xg_sprite-view" href="https://www.datasciencecentral.com/profiles/blog/list?user=3v6n5b6g08kgn">View Blog</a>]

# %%
# Check your answer here. (Do not make any change to this cell. Just run this cell.)
ans2_1, ans2_2
# Out:
# ('Vincent Granville', ' on February 2, 2021 at 10:30am')

# %% [markdown]
# 3\. Get the entire body text of the article, which starts with '*To zoom in on any picture,*' and ends with '*articles and books, here.*'. To clean the text, do the following:
# - Replace each new line ('\n') in the body text with a whitespace (' ')
# - Remove all '\xa0' characters.
# - Strip out all leading and trailing whitespaces.
#
# Save the resulting string in the variable `ans3`.

# %%
# Your answer here
ans3=soup.find('div',{"class":"postbody"}).text.replace("\n"," ").replace("\xa0","").lstrip().rstrip()

# %%
# Check your answer here. (Do not make any change to this cell. Just run this cell.)
ans3
# Out:
# 'To zoom in on any picture, click on the image to get a higher resolution.   Figure 1: The pillow basins (see section 3)  The topic discussed here is closely related to optimization techniques in machine learning. I will also talk about dynamic systems, especially discrete chaotic ones, in two dimensions. This is a fascinating branch of quantitative science, with numerous applications. This article provides you with an opportunity to gain exposure to this discipline, which is usually overlooked by data scientists but well studied by mathematicians and physicists. The images presented here are selected not just for their beauty, but most importantly for their intrinsic value: the practical insights that can be derived from them, and the implications for machine learning professionals.  1. Introduction to dynamical systems A discrete dynamical system is a sequence xn+1 = f(xn) where n is an integer, starting with n = 0 (the initial condition) and wherefis a real-valued function. In the continuous version (not discussed here), the index n (also called time)is a real number. The function f is called the map of the system, the system itself is also called a mapping: the most studied one is the logistic map defined by f(x) = ρx (1 - x), with x in [0, 1]. When ρ = 4, it is fully chaotic.The sequence (xn) for a specific initial condition x0, is called the orbit. Another example of chaotic mapping is the digits in base b of an irrational number z in [0,1]. In this case, x0 = z, f(x) = bx - INT(bx) and the n-th digit of z is INT(bxn). Here INT is the integer part function. It is studied in details in my bookApplied Stochastic Processes, Chaos Modeling, and Probabilistic Properties of Numeration Systems,available for free, here. See also the second, large appendix in my free bookStatistics: New Foundations, Toolbox, and Machine Learning Recipes, available here. Applications include the design of non-periodic pseudo-random number generators, cryptography, and even a new concept of number guessing (gambling or simulated stock market) where the winning numbers can be computed in advance with a public algorithm that requires trillions of years of computing time, while a fast, private algorithm is kept secret. See here. The concept easily generalizes to two dimensions. In this case xn is a vector or a complex number. Mappings in the complex plane are known to produce beautiful fractals; it has been used in fractal compression algorithms, to compress images. In one dimension, once in chaotic mode, they produce Brownian-like orbits, with applications in Fintech. 1.1. The sine map Moving forward, we focus exclusively on a particular case of the sine mapping, both in one and two dimensions. This is one of the most simple nonlinear mappings, yet it is very versatile and produces a large number of varied and intriguing configurations. In one dimension, it is defined as follows: xn+1 = -ρxn +λ sin(xn). In two dimensions, it is defined as xn+1 = -ρxn +λ sin(yn), yn+1 = -ρxn +λ sin(xn).  This system is governed by two real parameters:ρ andλ. Some of its properties and references are discussed here. 2. Connection to machine learning optimization algorithms I need to introduce two more concepts before getting down to the interesting stuff. The first one is called fixed point. Note that aroot is simply a value x* such that f(x*) = 0.Some systems don\'t have any root, some have one, some have several, and some have infinitely many, depending on the values of the parameters (in our case, depending onρ andλ, see section 1.1). Some or all roots can be found using the following fixed point recursion: xn+1 = xn + f(xn). In our case, this translates to using the following algorithm. 2.1. Fixed point algorithm For our sine mapping defined in section 1.1, proceed as follows xn+1 = xn -ρxn +λ sin(xn) in one dimension, or xn+1 = xn -ρxn +λ sin(yn), yn+1 = xn -ρxn +λ sin(xn), in two dimensions. If the sequences in question converge to some x* (one dimension) or x*,  ...

# %% [markdown]
# 4\. There are seven images in the body text. Print the URL of each image in order, seprarated by a new line. The printed output look as follows:

# %% [markdown]
# https://storage.ning.com/topology/rest/1.0/file/get/8505475867?profile=RESIZE_710x
# https://storage.ning.com/topology/rest/1.0/file/get/8505364456?profile=RESIZE_710x
# https://storage.ning.com/topology/rest/1.0/file/get/8507391075?profile=RESIZE_710x
# https://storage.ning.com/topology/rest/1.0/file/get/8507394283?profile=RESIZE_710x
# https://storage.ning.com/topology/rest/1.0/file/get/8507115889?profile=RESIZE_710x
# https://storage.ning.com/topology/rest/1.0/file/get/8507235501?profile=RESIZE_710x
# https://storage.ning.com/topology/rest/1.0/file/get/8572990262?profile=RESIZE_710x

# %%
# Your answer here
img_list=soup.find("div",{"class":"postbody"}).find_all('img',{"class":"align-center"})
for img in img_list:
  print(img.get("src"))
# Out:
# https://storage.ning.com/topology/rest/1.0/file/get/8505475867?profile=RESIZE_710x
# https://storage.ning.com/topology/rest/1.0/file/get/8505364456?profile=RESIZE_710x
# https://storage.ning.com/topology/rest/1.0/file/get/8507391075?profile=RESIZE_710x
# https://storage.ning.com/topology/rest/1.0/file/get/8507394283?profile=RESIZE_710x
# https://storage.ning.com/topology/rest/1.0/file/get/8507115889?profile=RESIZE_710x
# https://storage.ning.com/topology/rest/1.0/file/get/8507235501?profile=RESIZE_710x
# https://storage.ning.com/topology/rest/1.0/file/get/8572990262?profile=RESIZE_710x

# %% [markdown]
# <hr>

# %% [markdown]
# Next, you are going to extract information from another webpage on DataScienceCentral.com: https://www.datasciencecentral.com/profiles/blog/list?promoted=1&page=1. Fetch the HTML content from the webpage and then create a BeautifulSoup object named `soup2` to parse the HTML content.

# %%
# Your answer here
url="https://www.datasciencecentral.com/profiles/blog/list?promoted=1&page=1"
r=requests.get(url)
soup2=BeautifulSoup(r.content,"html.parser")

# %% [markdown]
# 5\. The webpage lists 20 featured blog posts. Print the title and URL of each blog post, such that the title is printed, followed by a colon, a space, the URL, and a new line. For example, the first three blog posts on the list are printed as below. Note that the titles and URLs could be different than yours, as the content of the webpage changes overt time.

# %% [markdown]
# Understanding the Role of Project Managers: https://www.datasciencecentral.com/profiles/blogs/who-is-a-pm-i-don-t-need-them<br>
# DSC Weekly Digest 19 October 2021: https://www.datasciencecentral.com/profiles/blogs/dsc-weekly-digest-19-october-2021<br>
# How Big Data and Geolocation Solutions Can Help Your Business: https://www.datasciencecentral.com/profiles/blogs/how-big-data-and-geolocation-solutions-can-help-your-business

# %%
# Your answer here
blogs=soup2.find_all("h3",{"class":"title"})
for blog in blogs:
  a = blog.find_all("a")[1]
  print(a.text+" : "+a['href'])
# Out:
# Top 5 Trends of Telematics Industry : https://www.datasciencecentral.com/profiles/blogs/top-5-trends-of-telematics-industry
# Accelerate The Move To Digital With Professional Ebook Conversion Services : https://www.datasciencecentral.com/profiles/blogs/accelerate-the-move-to-digital-with-professional-ebook-conversion
# Machine Learning as a Service - Opens Up Unimaginable Perspectives of Better Future : https://www.datasciencecentral.com/profiles/blogs/machine-learning-as-a-service-opens-up-unimaginable-perspectives
# Redefine e-Learning Software Development With These Three Trends : https://www.datasciencecentral.com/profiles/blogs/redefine-e-learning-software-development-with-these-3-trends
# 4 Trends in gaming that will reshape the industry : https://www.datasciencecentral.com/profiles/blogs/4-trends-in-gaming-that-will-reshape-the-industry
# NER or Named Entity Recognition Usage in NLP Tasks : https://www.datasciencecentral.com/profiles/blogs/ner-or-named-entity-recognition-usage-in-nlp-tasks
# Artificial Intelligence: Benefits for Automation Testing : https://www.datasciencecentral.com/profiles/blogs/artificial-intelligence-benefits-for-automation-testing
# Mastering the Data Economic Multiplier Effect and Marginal Propensity to Reuse : https://www.datasciencecentral.com/profiles/blogs/mastering-the-data-economic-multiplier-effect-and-marginal
# AI in Production: the Final Frontier : https://www.datasciencecentral.com/profiles/blogs/ai-in-production-the-final-frontier
# 7 ways IoT is impacting the eCommerce industry : https://www.datasciencecentral.com/profiles/blogs/7-ways-iot-is-impacting-the-ecommerce-industry
# DSC Weekly Digest 26 October 2021 : https://www.datasciencecentral.com/profiles/blogs/dsc-weekly-digest-26-october-2021
# The Disappearing Data Scientist : https://www.datasciencecentral.com/profiles/blogs/the-disappearing-data-scientist
# How Is Machine Learning Used For Stock Market Prediction? : https://www.datasciencecentral.com/profiles/blogs/how-is-machine-learning-used-for-stock-market-prediction-1
# The Product Management Process: 7 Important Stages for Startup : https://www.datasciencecentral.com/profiles/blogs/the-product-management-process-7-important-stages-for-startup
# How FinTech App Development Benefits Your Business? : https://www.datasciencecentral.com/profiles/blogs/how-fintech-app-development-benefits-your-business
# How Kubernetes Can Reduce Development and Deployment Costs : https://www.datasciencecentral.com/profiles/blogs/how-kubernetes-can-reduce-development-and-deployment-costs
# Features Part 3:  Features as Economic Assets : https://www.datasciencecentral.com/profiles/blogs/features-part-3-features-as-economic-assets
# Spark Troubleshooting, Part 2: Five Types of Solutions : https://www.datasciencecentral.com/profiles/blogs/spark-troubleshooting-part-2-five-types-of-solutions
# Smart Home as a Service : How Smart Homes Can Deliver Sustainability as a Service : https://www.datasciencecentral.com/profiles/blogs/smart-home-as-a-service-how-smart-homes-can-deliver-1
# Quantum Computing will Dramatically Increase Capabilities Beyond Classical Computing : https://www.datasciencecentral.com/profiles/blogs/quantum-computing-will-dramatically-increase-capabilities-beyond

# %% [markdown]
# <hr>

# %% [markdown]
# 6\. Click this link https://www.who.int/news-room/releases/1, which will lead you to the News Releases page of the World Health Organization (WHO). On that page, you should see ten links to the most recent news release pages. Click the page number 2 at the bottom, which will lead you to the second page, and you will see another ten links, and so on and so forth. Create a CSV file named hw2_output.csv in the outcome folder, such that the header row contains the two column names, title and url, and the following 50 rows contain the titles and full URLs of all the links in pages 1 to 5. For the CSV file, columns are separated by a tab and rows by a new line. While fetching the content from the web site, sleep for one second per page. The title text may have unnecessary strings '\r\n', so remove them all in the title text.
#
# For example, the first value in the title column is 'WHO and partners call for action to better protect health and care workers from COVID-19' and the first value in the url column is 'https://www.who.int/news/item/21-10-2021-who-and-partners-call-for-action-to-better-protect-health-and-care-workers-from-covid-19'. Note that the titles and URLs could be different than yours, as the content of the webpage changes overt time.

# %%
urls = []

for i in range(1, 6):     # The range(2, 101) generates a list of integers from 2 to 100.
    url = f" https://www.who.int/news-room/releases/{i}/"
    urls.append(url)
    
urls
import os
import time
with open(f"{outcome_folder}/hw2_output.csv", "w") as fw:
  fw.write("title\turl\n")
  for url in urls:
    print(url)
    r=requests.get(url)
    soup = BeautifulSoup(r.content, "html.parser")
  
    div_list=soup.find_all("div",{"class":"list-view--item vertical-list-item"})
    for div in div_list:
      # print(div)
      a=div.find("a")
      title=a.find("p").text.replace("\r\n","")
      url="https://www.who.int"+a['href']
      print(title+" : "+  url)
      fw.write(f"{title}\t{url}\n")
    time.sleep(1)
# Out:
#  https://www.who.int/news-room/releases/1/
# World Health Organization Secretariat announcement regarding the election of the next WHO Director-General : https://www.who.int/news/item/29-10-2021-world-health-organization-secretariat-announcement-regarding-the-election-of-the-next-who-director-general
# New ACT-Accelerator strategy calls for US$ 23.4 billion international investment to solve inequities in global access to COVID-19 vaccines, tests & treatments : https://www.who.int/news/item/28-10-2021-new-act-accelerator-strategy-calls-investment
# WHO launches the third edition Health for All Film Festival call for short films : https://www.who.int/news/item/28-10-2021-who-launches-the-third-edition-health-for-all-film-festival-call-for-short-films
# Peggy Maguire Appointed to the WHO Academy Quality Committee Board : https://www.who.int/news/item/27-10-2021-peggy-maguire-appointed-to-the-who-academy-quality-committee-board
# Top economists call for radical redirection of the economy to put Health for All at the centre in the run-up to G20 : https://www.who.int/news/item/26-10-2021-top-economists-call-for-radical-redirection-of-the-economy-to-put-health-for-all-at-the-centre-in-the-run-up-to-g20
