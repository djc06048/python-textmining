# %% [markdown]
# # Software Coaching for Python
# # Week 2: Advanced Web Scraping

# %% [markdown]
# Instructor: Kang-Pyo Lee

# %%
from google.colab import drive

drive.mount('/content/gdrive')
path = "/content/gdrive/Shareddrives/Software_Coaching_Fall_2021"
my_folder = "HLP"     # *** REPLACE WITH YOUR FOLDER NAME ***
outcome_folder = f"{path}/{my_folder}/outcome"
# Out:
# Mounted at /content/gdrive

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Handle pagination

# %%
urls = ["https://fivethirtyeight.com/features/"]

for i in range(2, 101):     # The range(2, 101) generates a list of integers from 2 to 100.
    url = f"https://fivethirtyeight.com/features/page/{i}/"
    urls.append(url)
    
urls
# Out:
# ['https://fivethirtyeight.com/features/',
#  'https://fivethirtyeight.com/features/page/2/',
#  'https://fivethirtyeight.com/features/page/3/',
#  'https://fivethirtyeight.com/features/page/4/',
#  'https://fivethirtyeight.com/features/page/5/',
#  'https://fivethirtyeight.com/features/page/6/',
#  'https://fivethirtyeight.com/features/page/7/',
#  'https://fivethirtyeight.com/features/page/8/',
#  'https://fivethirtyeight.com/features/page/9/',
#  'https://fivethirtyeight.com/features/page/10/',
#  'https://fivethirtyeight.com/features/page/11/',
#  'https://fivethirtyeight.com/features/page/12/',
#  'https://fivethirtyeight.com/features/page/13/',
#  'https://fivethirtyeight.com/features/page/14/',
#  'https://fivethirtyeight.com/features/page/15/',
#  'https://fivethirtyeight.com/features/page/16/',
#  'https://fivethirtyeight.com/features/page/17/',
#  'https://fivethirtyeight.com/features/page/18/',
#  'https://fivethirtyeight.com/features/page/19/',
#  'https://fivethirtyeight.com/features/page/20/',
#  'https://fivethirtyeight.com/features/page/21/',
#  'https://fivethirtyeight.com/features/page/22/',
#  'https://fivethirtyeight.com/features/page/23/',
#  'https://fivethirtyeight.com/features/page/24/',
#  'https://fivethirtyeight.com/features/page/25/',
#  'https://fivethirtyeight.com/features/page/26/',
#  'https://fivethirtyeight.com/features/page/27/',
#  'https://fivethirtyeight.com/features/page/28/',
#  'https://fivethirtyeight.com/features/page/29/',
#  'https://fivethirtyeight.com/features/page/30/',
#  'https://fivethirtyeight.com/features/page/31/',
#  'https://fivethirtyeight.com/features/page/32/',
#  'https://fivethirtyeight.com/features/page/33/',
#  'https://fivethirtyeight.com/features/page/34/',
#  'https://fivethirtyeight.com/features/page/35/',
#  'https://fivethirtyeight.com/features/page/36/',
#  'https://fivethirtyeight.com/features/page/37/',
#  'https://fivethirtyeight.com/features/page/38/',
#  'https://fivethirtyeight.com/features/page/39/',
#  'https://fivethirtyeight.com/features/page/40/',
#  'https://fivethirtyeight.com/features/page/41/',
#  'https://fivethirtyeight.com/features/page/42/',
#  'https://fivethirtyeight.com/features/page/43/',
#  'https://fivethirtyeight.com/features/page/44/',
#  'https://fivethirtyeight.com/features/page/45/',
#  'https://fivethirtyeight.com/features/page/46/',
#  'https://fivethirtyeight.com/features/page/47/',
#  'https://fivethirtyeight.com/features/page/48/',
#  'https://fivethirtyeight.com/features/page/49/',
#  'https://fivethirtyeight.com/features/page/50/',
#  'https://fivethirtyeight.com/features/page/51/',
#  'https://fivethirtyeight.com/features/page/52/',
#  'https://fivethirtyeight.com/features/page/53/',
#  'https://fivethirtyeight.com/features/page/54/',
#  'https://fivethirtyeight.com/features/page/55/',
#  'https://fivethirtyeight.com/features/page/56/',
#  'https://fivethirtyeight.com/features/page/57/',
#  'https://fivethirtyeight.com/features/page/58/',
#  'https://fivethirtyeight.com/features/page/59/',
#  'https://fivethirtyeight.com/features/page/60/',
#  'https://fivethirtyeight.com/features/page/61/',
#  'https://fivethirtyeight.com/features/page/62/',
#  'https://fivethirtyeight.com/features/page/63/',
#  'https://fivethirtyeight.com/features/page/64/',
#  'https://fivethirtyeight.com/features/page/65/',
#  'https://fivethirtyeight.com/features/page/66/',
#  'https://fivethirtyeight.com/features/page/67/',
#  'https://fivethirtyeight.com/features/page/68/',
#  'https://fivethirtyeight.com/features/page/69/',
#  'https://fivethirtyeight.com/features/page/70/',
#  'https://fivethirtyeight.com/features/page/71/',
#  'https://fivethirtyeight.com/features/page/72/',
#  'https://fivethirtyeight.com/features/page/73/',
#  'https://fivethirtyeight.com/features/page/74/',
#  'https://fivethirtyeight.com/features/page/75/',
#  'https://fivethirtyeight.com/features/page/76/',
#  'https://fivethirtyeight.com/features/page/77/',
#  'https://fivethirtyeight.com/features/page/78/',
#  'https://fivethirtyeight.com/features/page/79/',
#  'https://fivethirtyeight.com/features/page/80/',
#  'https://fivethirtyeight.com/features/page/81/',
#  'https://fivethirtyeight.com/features/page/82/',
#  'https://fivethirtyeight.com/features/page/83/',
#  'https://fivethirtyeight.com/features/page/84/',
#  'https://fivethirtyeight.com/features/page/85/',
#  'https://fivethirtyeight.com/features/page/86/',
#  'https://fivethirtyeight.com/features/page/87/',
#  'https://fivethirtyeight.com/features/page/88/',
#  'https://fivethirtyeight.com/features/page/89/',
#  'https://fivethirtyeight.com/features/page/90/',
#  'https://fivethirtyeight.com/features/page/91/',
#  'https://fivethirtyeight.com/features/page/92/',
#  'https://fivethirtyeight.com/features/page/93/',
#  'https://fivethirtyeight.com/features/page/94/',
#  'https://fivethirtyeight.com/features/page/95/',
#  'https://fivethirtyeight.com/features/page/96/',
#  'https://fivethirtyeight.com/features/page/97/',
#  'https://fivethirtyeight.com/features/page/98/',
#  'https://fivethirtyeight.com/features/page/99/',
#  'https://fivethirtyeight.com/features/page/100/']

# %% [markdown]
# Try to get all of the URLs of the target webpages first before trying to get the contents from those webpages. At this point, it is important to find a rule for creating the URLs.

# %%
for url in urls:
    print(url)              # Do whatever you want with each web page.
# Out:
# https://fivethirtyeight.com/features/
# https://fivethirtyeight.com/features/page/2/
# https://fivethirtyeight.com/features/page/3/
# https://fivethirtyeight.com/features/page/4/
# https://fivethirtyeight.com/features/page/5/
# https://fivethirtyeight.com/features/page/6/
# https://fivethirtyeight.com/features/page/7/
# https://fivethirtyeight.com/features/page/8/
# https://fivethirtyeight.com/features/page/9/
# https://fivethirtyeight.com/features/page/10/
# https://fivethirtyeight.com/features/page/11/
# https://fivethirtyeight.com/features/page/12/
# https://fivethirtyeight.com/features/page/13/
# https://fivethirtyeight.com/features/page/14/
# https://fivethirtyeight.com/features/page/15/
# https://fivethirtyeight.com/features/page/16/
# https://fivethirtyeight.com/features/page/17/
# https://fivethirtyeight.com/features/page/93/
# https://fivethirtyeight.com/features/page/94/
# https://fivethirtyeight.com/features/page/95/
# https://fivethirtyeight.com/features/page/96/
# https://fivethirtyeight.com/features/page/97/
# https://fivethirtyeight.com/features/page/98/
# https://fivethirtyeight.com/features/page/99/
# https://fivethirtyeight.com/features/page/100/

# %% [markdown]
# ## Write & read an HTML file

# %%
url = "https://fivethirtyeight.com/features/why-was-the-national-polling-environment-so-off-in-2020/"
r = requests.get(url)
# Out:
# <Response [200]>

# %%
url[len("https://fivethirtyeight.com/features/"):-1]
# Out:
# 'why-was-the-national-polling-environment-so-off-in-2020'

# %%
file_name = url[len("https://fivethirtyeight.com/features/"):-1] + ".html"
file_name
# Out:
# 'why-was-the-national-polling-environment-so-off-in-2020.html'

# %%
with open(f"{outcome_folder}/{file_name}", "w+b") as fw: 
    fw.write(r.content)

# %%
with open(f"{outcome_folder}/{file_name}", "r+b") as fr:
    soup = BeautifulSoup(fr.read(), "html.parser")
    
    print(soup.title.text)          # Do whatever you want with the saved web page.
# Out:
# Why Was The National Polling Environment So Off In 2020? | FiveThirtyEight

# %% [markdown]
# ## Automate the process of saving all articles on the Features list

# %%
urls = ["https://fivethirtyeight.com/features/"]

for i in range(2, 10):     # The range(2, 10) generates a list of integers from 2 to 9.
    url = f"https://fivethirtyeight.com/features/page/{i}/"
    urls.append(url)

urls
# Out:
# ['https://fivethirtyeight.com/features/',
#  'https://fivethirtyeight.com/features/page/2/',
#  'https://fivethirtyeight.com/features/page/3/',
#  'https://fivethirtyeight.com/features/page/4/',
#  'https://fivethirtyeight.com/features/page/5/',
#  'https://fivethirtyeight.com/features/page/6/',
#  'https://fivethirtyeight.com/features/page/7/',
#  'https://fivethirtyeight.com/features/page/8/',
#  'https://fivethirtyeight.com/features/page/9/']

# %%
import os

if not os.path.isdir(f"{outcome_folder}/HTMLs"):
    os.mkdir(f"{outcome_folder}/HTMLs")

# %%
import time     # Necessary for the sleep function.

# %%
for url in urls:
    print(url)
    
    ####################################################
    # Get the content of a page
    ####################################################
    r = requests.get(url)
    soup = BeautifulSoup(r.content, "html.parser")
    
    ####################################################
    # Get the list of articles
    ####################################################
    h2_list = soup.find_all("h2", {"class": "article-title entry-title"})
    
    for h2 in h2_list:
        ####################################################
        # Find the anchor tag
        ####################################################
        a = h2.find("a")
        
        ####################################################
        # Extract the title & URL of an article
        ####################################################
        title = a.text
        article_url = a["href"]
        
        ####################################################
        # Fetch the content and save it as an HTML file
        ####################################################
        print("- " + article_url + ": processing...")
        
        r2 = requests.get(article_url)
                
        if "/features/" in article_url:
          file_name = article_url[len("https://fivethirtyeight.com/features/"):-1] + ".html"
        elif "/videos/" in article_url:
          file_name = article_url[len("https://fivethirtyeight.com/videos/"):-1] + ".html"
        elif "/methodology/" in article_url:
          file_name = article_url[len("https://fivethirtyeight.com/methodology/"):-1] + ".html"
        else:
          assert 0 == 1, "Unknown article url pattern!"

        with open(f"{outcome_folder}/HTMLs/{file_name}", "w+b") as fw:
            fw.write(r2.content)
        
        print("- " + file_name + ": saved.")
        
        ####################################################
        # Sleep for a second to not overload the web site
        ####################################################
        time.sleep(1)
    
    print()
# Out:
# https://fivethirtyeight.com/features/
# - https://fivethirtyeight.com/features/the-red-sox-seemed-unstoppable-then-the-astros-turned-the-tables/: processing...
# - the-red-sox-seemed-unstoppable-then-the-astros-turned-the-tables.html: saved.
# - why-house-democrats-may-be-more-united-than-they-seem.html: saved.
# - https://fivethirtyeight.com/features/yes-college-footballs-playoff-race-really-is-more-wide-open-than-usual/: processing...
# - yes-college-footballs-playoff-race-really-is-more-wide-open-than-usual.html: saved.
# - https://fivethirtyeight.com/features/why-the-underdogs-have-a-shot-in-the-wnba-semifinals/: processing...
# - why-the-underdogs-have-a-shot-in-the-wnba-semifinals.html: saved.
# - https://fivethirtyeight.com/features/how-arkansas-revived-its-program/: processing...
# - how-arkansas-revived-its-program.html: saved.
# - https://fivethirtyeight.com/features/when-it-comes-to-china-biden-sounds-a-lot-like-trump/: processing...
# - when-it-comes-to-china-biden-sounds-a-lot-like-trump.html: saved.
# - https://fivethirtyeight.com/features/bryce-harper-didnt-need-luck-for-an-mvp-level-season/: processing...
# - bryce-harper-didnt-need-luck-for-an-mvp-level-season.html: saved.
# - https://fivethirtyeight.com/videos/will-democrats-get-their-agenda-passed/: processing...
# - will-democrats-get-their-agenda-passed.html: saved.
# - https://fivethirtyeight.com/features/texass-new-congressional-map-could-give-a-huge-boost-to-gop-incumbents/: processing...
# - texass-new-congressional-map-could-give-a-huge-boost-to-gop-incumbents.html: saved.

# %% [markdown]
# ## Extract information from all HTML files & save it in a CSV file

# %%
os.listdir(f"{outcome_folder}/HTMLs")
# Out:
# ['the-red-sox-seemed-unstoppable-then-the-astros-turned-the-tables.html',
#  'who-betrayed-dunes-duke-leto.html',
#  'adam-schiff-says-theres-no-magic-button-to-push-to-protect-democracy.html',
#  'a-majority-of-republican-voters-actively-want-trump-to-run-for-president-again.html',
#  'the-accs-best-playoff-hope-is-pittsburgh-yes-really.html',
#  'the-raiders-had-more-black-players-than-any-nfl-team-then-jon-gruden-took-over-the-roster.html',
#  'biden-has-lost-support-across-all-groups-of-americans-but-especially-independents-and-hispanics.html',
#  'how-democrats-failure-to-pass-a-voting-rights-bill-fits-a-pattern-of-failing-voters-of-color.html',
#  'many-of-the-nhls-best-teams-are-still-getting-to-know-their-goalies.html',
#  'anthony-edwards-found-his-rhythm-late-last-season-can-he-help-minnesota-find-the-playoffs.html',
#  'the-roberts-court-vs-the-trump-court.html',
#  'the-polls-consistently-show-a-close-governors-race-in-virginia.html',
#  'how-enrique-hernandez-went-from-utility-infielder-to-the-hottest-hitter-in-the-playoffs.html',
#  'why-democratic-gains-in-texass-big-metro-areas-could-outweigh-republican-success-in-south-texas.html',
#  'the-fouls-you-wont-see-on-3-point-shots-this-season-and-some-you-still-will.html',
#  'can-the-chicago-sky-keep-their-championship-core-intact.html',
#  'which-of-the-nfls-top-teams-have-been-lucky-and-which-are-actually-good.html',
#  'do-you-buy-that-limiting-abortion-access-will-mobilize-democrats-at-the-polls.html',
#  'how-mitch-mcconnell-accidentally-created-an-unregulated-thc-market.html',
#  'local-news-is-vanishing-what-does-that-mean-for-american-politics.html',
#  'can-you-hit-these-riddles-out-of-the-park.html',
#  'justin-herbert-and-lamar-jackson-are-crushing-it-on-different-downs.html',
#  'why-the-virginia-governors-race-is-so-close.html',
#  'the-fight-over-covid-19-vaccine-mandates-is-coming-to-kids-next.html',
#  'why-the-underdogs-have-a-shot-in-the-wnba-semifinals.html',
#  'how-arkansas-revived-its-program.html',
#  'when-it-comes-to-china-biden-sounds-a-lot-like-trump.html',
#  'bryce-harper-didnt-need-luck-for-an-mvp-level-season.html',
#  'will-democrats-get-their-agenda-passed.html',
#  'texass-new-congressional-map-could-give-a-huge-boost-to-gop-incumbents.html']

# %%
html_files = [file for file in os.listdir(f"{outcome_folder}/HTMLs") if file.endswith(".html")]
html_files
# Out:
# ['the-red-sox-seemed-unstoppable-then-the-astros-turned-the-tables.html',
#  'who-betrayed-dunes-duke-leto.html',
#  'adam-schiff-says-theres-no-magic-button-to-push-to-protect-democracy.html',
#  'a-majority-of-republican-voters-actively-want-trump-to-run-for-president-again.html',
#  'the-accs-best-playoff-hope-is-pittsburgh-yes-really.html',
#  'the-raiders-had-more-black-players-than-any-nfl-team-then-jon-gruden-took-over-the-roster.html',
#  'biden-has-lost-support-across-all-groups-of-americans-but-especially-independents-and-hispanics.html',
#  'how-democrats-failure-to-pass-a-voting-rights-bill-fits-a-pattern-of-failing-voters-of-color.html',
#  'many-of-the-nhls-best-teams-are-still-getting-to-know-their-goalies.html',
#  'anthony-edwards-found-his-rhythm-late-last-season-can-he-help-minnesota-find-the-playoffs.html',
#  'the-roberts-court-vs-the-trump-court.html',
#  'the-polls-consistently-show-a-close-governors-race-in-virginia.html',
#  'how-enrique-hernandez-went-from-utility-infielder-to-the-hottest-hitter-in-the-playoffs.html',
#  'why-democratic-gains-in-texass-big-metro-areas-could-outweigh-republican-success-in-south-texas.html',
#  'the-fouls-you-wont-see-on-3-point-shots-this-season-and-some-you-still-will.html',
#  'can-the-chicago-sky-keep-their-championship-core-intact.html',
#  'which-of-the-nfls-top-teams-have-been-lucky-and-which-are-actually-good.html',
#  'do-you-buy-that-limiting-abortion-access-will-mobilize-democrats-at-the-polls.html',
#  'how-mitch-mcconnell-accidentally-created-an-unregulated-thc-market.html',
#  'local-news-is-vanishing-what-does-that-mean-for-american-politics.html',
#  'can-you-hit-these-riddles-out-of-the-park.html',
#  'justin-herbert-and-lamar-jackson-are-crushing-it-on-different-downs.html',
#  'why-the-virginia-governors-race-is-so-close.html',
#  'the-fight-over-covid-19-vaccine-mandates-is-coming-to-kids-next.html',
#  'giants-or-dodgers-game-5s-winner-will-be-in-the-world-series-drivers-seat.html',
#  'will-the-bucks-run-it-back-can-lebron-win-his-fifth-ring-how-our-model-sees-the-2021-22-nba-season.html',
#  'is-there-anything-candace-parker-cant-do.html',
#  'the-cowboys-are-putting-it-all-together-is-this-their-year.html',
#  'why-abortion-may-now-motivate-democrats-more-than-republicans.html',
#  'it-looks-like-house-democrats-are-worried-about-the-2022-midterms.html',
#  'georgias-defense-isnt-just-good-it-might-be-best-ever-good.html',
#  'why-has-bidens-approval-rating-gotten-so-low-so-quickly.html',
#  'the-brooklyn-nets-could-use-as-many-as-7-centers-but-they-all-bring-something-different.html',
#  'is-government-about-to-regulate-facebook.html',
#  'a-week-to-forget-for-nfl-kickers.html',
#  'can-the-lightning-three-peat-how-good-will-the-kraken-be-the-storylines-to-follow-this-nhl-season.html',
#  'kyrsten-sinema-is-confounding-her-own-party-but-why.html',
#  'how-carmelo-anthony-can-help-the-lakers.html',
#  'can-you-evade-your-evil-twin.html',
#  'americans-want-the-government-to-act-on-climate-change-whats-the-hold-up.html',
#  'college-football-teams-are-scoring-more-than-ever-big-ten-defenses-dont-care.html',
#  'why-the-u-s-was-unprepared-for-covid-according-to-the-former-fda-chief.html',
#  'the-debt-ceiling-is-dangerous-but-its-probably-not-going-away-anytime-soon.html',
#  'the-broncos-and-panthers-looked-like-world-beaters-a-week-ago-what-happened.html',
#  'how-our-nhl-predictions-work.html',
#  'what-our-new-nhl-forecast-says-about-this-season.html',
#  'murders-spiked-in-2020-how-will-that-change-the-politics-of-crime.html',
#  'is-the-nfc-west-the-toughest-division-in-nfl-history.html',
#  'these-wnba-stars-are-back-on-the-court-at-just-the-right-time.html',
#  'bidens-approval-rating-isnt-bouncing-back.html',
#  'the-nbas-revolution-in-pull-up-threes-isnt-going-away-but-does-the-shot-actually-help.html',
#  'why-past-hurricane-seasons-dont-tell-us-much-about-the-future.html',
#  'are-democrats-dysfunctional-or-just-disagreeing.html',
#  'are-the-democrats-really-that-far-from-passing-bidens-agenda.html',
#  'tom-bradys-return-gave-us-everything-except-a-well-played-game.html',
#  'tampas-teams-are-on-one-hell-of-a-winning-streak.html',
#  'do-you-buy-that-democrats-should-worry-about-the-virginia-governors-race.html',
#  'why-the-supreme-court-probably-doesnt-care-what-most-americans-think-about-abortion-or-gun-rights.html',
#  'the-burning-questions-each-world-series-contender-needs-to-answer.html',
#  'can-you-power-through-the-workout.html',
#  'the-rams-and-matthew-stafford-have-each-leveled-up.html',
#  'what-americans-think-about-the-fight-over-the-debt-ceiling.html',
#  'where-breitbarts-false-claim-that-democrats-want-republicans-to-stay-unvaccinated-came-from.html',
#  'what-the-latest-crime-data-can-and-cant-tell-us.html',
#  'sadio-mane-never-went-away.html',
#  'why-some-white-evangelicals-are-rethinking-their-politics.html',
#  'white-evangelical-and-progressive.html',
#  'these-rookie-qbs-are-in-a-terrible-league-of-their-own.html',
#  'we-polled-members-of-congress-about-baseball.html',
#  'why-house-democrats-may-be-more-united-than-they-seem.html',
#  'yes-college-footballs-playoff-race-really-is-more-wide-open-than-usual.html',
#  'why-the-underdogs-have-a-shot-in-the-wnba-semifinals.html',
#  'how-arkansas-revived-its-program.html',
#  'when-it-comes-to-china-biden-sounds-a-lot-like-trump.html',
#  'bryce-harper-didnt-need-luck-for-an-mvp-level-season.html',
#  'will-democrats-get-their-agenda-passed.html',
#  'texass-new-congressional-map-could-give-a-huge-boost-to-gop-incumbents.html']

# %%
with open(f"{outcome_folder}/html_metadata.csv", "w") as fw:
    ####################################################
    # Column names on the first row
    ####################################################
    fw.write("file_name\tarticle_title\tarticle_author\n")   # A tab between columns and a new line between rows  

    for file_name in html_files:
        ####################################################
        # Column values starting from the second row
        ####################################################
        with open(f"{outcome_folder}/HTMLs/{file_name}", "r+b") as fr:
            print(file_name)
            soup = BeautifulSoup(fr.read(), "html.parser")
            
            article_title = soup.find("h1", {"class": "article-title article-title-single entry-title"}).text.strip()
            article_author = soup.find("a", {"class": "author url fn"}).text
            
            #####################################################################
            # Remove all possible tabs, as tab is being used as column delimiter
            #####################################################################
            article_title = article_title.replace("\t", "")
            article_aurthor = article_author.replace("\t", "")
            
            fw.write(f"{file_name}\t{article_title}\t{article_author}\n")
# Out:
# the-red-sox-seemed-unstoppable-then-the-astros-turned-the-tables.html
# who-betrayed-dunes-duke-leto.html
# adam-schiff-says-theres-no-magic-button-to-push-to-protect-democracy.html
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-29da9304f2ed> in <module>()
#      13             soup = BeautifulSoup(fr.read(), "html.parser")
#      14             article_title = soup.find("h1", {"class": "article-title article-title-single entry-title"}).text.strip()
# ---> 15             article_author = soup.find("a", {"class": "author url fn"}).text
#      16
#      17             #####################################################################
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
with open(f"{outcome_folder}/html_metadata.csv", "w") as fw:
    ####################################################
    # Column names on the first row
    ####################################################
    fw.write("file_name\tarticle_title\tarticle_author\n")

    for file_name in os.listdir(f"{outcome_folder}/HTMLs"):
        if not file_name.endswith(".html"):
            continue
        
        ####################################################
        # Column values starting from the second row
        ####################################################
        with open(f"{outcome_folder}/HTMLs/{file_name}", "r+b") as fr:
            print(file_name)
            soup = BeautifulSoup(fr.read(), "html.parser")
            article_title = soup.find("h1", {"class": "article-title article-title-single entry-title"}).text.strip()
            
            ####################################################
            # No author exception handling
            ####################################################
            if soup.find("a", {"class": "author url fn"}) == None:
                article_author = ""
            else:
                article_author = soup.find("a", {"class": "author url fn"}).text
            
            ####################################################
            # Remove all possible tabs
            ####################################################
            article_title = article_title.replace("\t", "")
            article_aurthor = article_author.replace("\t", "")
                        
            fw.write(f"{file_name}\t{article_title}\t{article_author}\n")
# Out:
# the-red-sox-seemed-unstoppable-then-the-astros-turned-the-tables.html
# who-betrayed-dunes-duke-leto.html
# adam-schiff-says-theres-no-magic-button-to-push-to-protect-democracy.html
# a-majority-of-republican-voters-actively-want-trump-to-run-for-president-again.html
# the-accs-best-playoff-hope-is-pittsburgh-yes-really.html
# the-raiders-had-more-black-players-than-any-nfl-team-then-jon-gruden-took-over-the-roster.html
# biden-has-lost-support-across-all-groups-of-americans-but-especially-independents-and-hispanics.html
# how-democrats-failure-to-pass-a-voting-rights-bill-fits-a-pattern-of-failing-voters-of-color.html
# many-of-the-nhls-best-teams-are-still-getting-to-know-their-goalies.html
# anthony-edwards-found-his-rhythm-late-last-season-can-he-help-minnesota-find-the-playoffs.html
# the-roberts-court-vs-the-trump-court.html
# the-polls-consistently-show-a-close-governors-race-in-virginia.html
# how-enrique-hernandez-went-from-utility-infielder-to-the-hottest-hitter-in-the-playoffs.html
# why-democratic-gains-in-texass-big-metro-areas-could-outweigh-republican-success-in-south-texas.html
# the-fouls-you-wont-see-on-3-point-shots-this-season-and-some-you-still-will.html
# can-the-chicago-sky-keep-their-championship-core-intact.html
# which-of-the-nfls-top-teams-have-been-lucky-and-which-are-actually-good.html
# do-you-buy-that-limiting-abortion-access-will-mobilize-democrats-at-the-polls.html
# how-mitch-mcconnell-accidentally-created-an-unregulated-thc-market.html
# local-news-is-vanishing-what-does-that-mean-for-american-politics.html
# can-you-hit-these-riddles-out-of-the-park.html
# justin-herbert-and-lamar-jackson-are-crushing-it-on-different-downs.html
# why-the-virginia-governors-race-is-so-close.html
# the-fight-over-covid-19-vaccine-mandates-is-coming-to-kids-next.html
# giants-or-dodgers-game-5s-winner-will-be-in-the-world-series-drivers-seat.html
